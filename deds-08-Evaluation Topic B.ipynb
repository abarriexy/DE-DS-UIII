# %% [markdown]
# <center><h1><strong><font color="blue"> Data Engineering for Data Science - Week 09</font></strong></h1></center>
#
# <center><img alt="" src="images/cover.png" style="height: 600px;"/></center>
#
# <center><h2><strong><font color="blue">Evaluations Topic B</font></strong></h2></center>
#
# <b><center><h3>(C) Taufik Sutanto</h3></center>

# %% [markdown]
# <center><h1><strong><font color="red">Next Session: Topic C - Introduction to Cloud Technology</font></strong></h1></center>
#
# ## "Tuesday", 12 May 2026

# %% [markdown]
# <center><h2><strong><font color="blue">End of Module</font></strong></h2></center>
#
# <center><img alt="" src="images/meme-cartoon/meme-what-is-SQL.jpeg" style="height: 600px;"/></center>
